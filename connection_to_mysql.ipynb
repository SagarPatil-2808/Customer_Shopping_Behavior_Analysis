# %%
import pandas as pd

# %%
df = pd.read_csv("cleaned_customer_shopping_behavior.csv")

# %%
df.head()
# Out:
#    customer_id  age gender item_purchased  category  purchase_amount(usd)  \
# 0            1   55   Male         Blouse  Clothing                    53
# 1            2   19   Male        Sweater  Clothing                    64
# 2            3   50   Male          Jeans  Clothing                    73
# 3            4   21   Male        Sandals  Footwear                    90
# 4            5   45   Male         Blouse  Clothing                    49
#
#         location size      color  season  review_rating subscription_status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %% [markdown]
# #

# %%
from sqlalchemy import create_engine

# %%
# Step 1: Connect to MySQL
username = "root"
password = "Sagar%402887"
host = "localhost"
port = "3306"
database = "customer_shopping_behavior"

engine = create_engine(f"mysql+pymysql://{username}:{password}@{host}/{database}")

# %%
# Step 2: Load DataFrame into MySQL
table_name = "cumstomer"
df.to_sql(table_name, engine, if_exists="replace", index=False)
print(f"Data sucssefully loaded into table {table_name} in database {database}")
# Out:
# Data sucssefully loaded into table cumstomer in database customer_shopping_behavior
